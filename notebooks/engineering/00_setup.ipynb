# %% [markdown]
# # 00 — Setup (run once per cluster)
#
# Install dependencies from `pyproject.toml`. Run this notebook **once** when you first attach a cluster; packages are then available to all notebooks.

# %%
from pathlib import Path
import sys
import subprocess

root = Path.cwd()
for _ in range(3):
    if (root / "pyproject.toml").exists():
        break
    root = root.parent

subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", str(root), "-q"])
print(f"Installed pokedata and deps from {root}")
